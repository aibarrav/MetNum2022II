# %% [markdown]
# <a href="https://colab.research.google.com/github/aibarrav/MetNumUN2022II/blob/main/Lab3/aibarrav_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Curso (1).png](data:image/png;base64,...)

# %% [markdown]
# ![curso 1.png](data:image/png;base64,...)

# %% [markdown]
# ![cURSO 3.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Linkedln.jpg](data:image/jpeg;base64,...)
